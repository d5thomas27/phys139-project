# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import sqlite3
import pymatching

# %%
# Initialize Dataset
import surf17_test.db
import surf17_train.db
import surf17_validation.db
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Initialize Dataset
# ----> 2 import surf17_test.db
#       3 import surf17_train.db
#       4 import surf17_validation.db
#
# ModuleNotFoundError: No module named 'surf17_test'

# %%
model = models.sequential([
    layers.Flatten(input_shape = (X_train))
])

# %%
# Test pull
